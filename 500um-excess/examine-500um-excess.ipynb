# %% [markdown]
# # Analysis of 500 $\mu$m excess ($\beta_{cold}$ = Free, $T_{warm} = 60$ K)

# %% [markdown]
# This notebook is meant to upload and take a look at the measured 500 $\mu$m excess using a two temperature modified blackbody to model the 22-500 $\mu$m SED. In this run, I fixed $T_{warm} = 60$ K and left $\beta_{cold}$ to be a free parameter.

# %% [markdown]
# First we need to gather all of the 500 $\mu$m excess measurements. For each source, a Python `pickle` file was created that saved a dictionary containing the 500 $\mu$m excess measurements for every modeled SED during the MCMC chain as well as the 2.5, 16, 50, 84, and 97.5 percentiles.

# %% [markdown]
# For this run all of the excess .pickle files are stored in ~/Research/Thesis/spire-catalog-analysis/500um-excess/results/betaFree/excess500. The files are named *Name*_betafree_twotemp_500excess.pickle where *Name* is the name of the source in our catalog. We can grab all of the files using `glob.glob`.

# %%
# %matplotlib inline

# Plotting packages
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
blue, green, red, purple, yellow, cyan = sns.color_palette('deep') # Better colors

# Analysis packages
import numpy as np
import pandas as pd
import pickle

# %%
from glob import glob
excess_dir = '/Users/ttshimiz/Research/Thesis/spire-catalog-analysis/500um-excess/results/betaFree/excess500/'
file_name = '*.pickle'

files = glob(excess_dir+file_name)

print files[0]
# Out:
# /Users/ttshimiz/Research/Thesis/spire-catalog-analysis/500um-excess/results/betaFree/excess500/2MASXJ07595347+2323241_betaFree_twotemp_500excess.pickle

# %% [markdown]
# We can pull out the names of the sources from each filename by splitting first by "\" and then by "_".

# %%
names = [x.split('/')[-1].split('_')[0] for x in files]
print names
# Out:
# ['2MASXJ07595347+2323241', '2MASXJ10402231-4625264', '2MASXJ12005792+0648226', '2MASXJ12313717-4758019', '2MASXJ15115979-2119015', '2MASXJ19373299-0613046', '2MASXJ21355399+4728217', '2MASXJ23272195+1524375', '2MFGC02280', '3C111.0', '3C120', '6dFJ0626586-370559', 'Ark120', 'CenA', 'CGCG341-006', 'CGCG468-002NED01', 'ESO005-G004', 'ESO033-G002', 'ESO137-34', 'ESO139-G012', 'ESO197-G027', 'ESO244-IG030', 'ESO297-018', 'ESO323-077', 'ESO362-18', 'ESO374-G044', 'ESO399-20', 'ESO439-G009', 'ESO490-IG026', 'ESO499-G041', 'ESO509-IG066NED01', 'ESO511-G030', 'ESO533-G050', 'ESO548-G081', 'ESO549-G049', 'ESO565-G019', 'Fairall272', 'Fairall49', 'HB890241+622', 'IC0486', 'IC1657', 'IC1816', 'IC2461', 'IC2637', 'IC4518A', 'IC5063', 'LEDA170194', 'M106', 'MCG+00-09-042', 'MCG+02-21-013', 'MCG+02-57-002', 'MCG+04-22-042', 'MCG+04-48-002', 'MCG+05-03-013', 'MCG+06-16-028', 'MCG+06-24-008', 'MCG+08-11-011', 'MCG+12-10-067', 'MCG-01-05-047', 'MCG-01-24-012', 'MCG-01-30-041', 'MCG-01-33-063', 'MCG-02-12-050', 'Mrk1018', 'Mrk10', 'Mrk1392', 'Mrk18', 'Mrk348', 'Mrk590', 'Mrk618', 'Mrk739E', 'Mrk766', 'Mrk79', 'Mrk817', 'NGC1106', 'NGC1365', 'NGC2655', 'NGC2885', 'NGC2992', 'NGC3035', 'NGC3079', 'NGC3081', 'NGC3227', 'NGC3281', 'NGC3393', 'NGC3431', 'NGC3718', 'NGC3783', 'NGC3786', 'NGC4051', 'NGC4102', 'NGC4138', 'NGC4151', 'NGC4180', 'NGC4235', 'NGC424', 'NGC4388', 'NGC4507', 'NGC4619', 'NGC4748', 'NGC4939', 'NGC4941', 'NGC4992', 'NGC5033', 'NGC5106', 'NGC513', 'NGC5231', 'NGC5290', 'NGC5506', 'NGC5610', 'NGC5674', 'NGC5728', 'NGC5899', 'NGC5995', 'NGC6221', 'NGC6240', 'NGC6300', 'NGC6814', 'NGC6860', 'NGC7172', 'NGC7213', 'NGC7465', 'NGC7469', 'NGC7479', 'NGC7582', 'NGC7603', 'NGC7679', 'NGC931', 'NGC985', 'PICTORA', 'PKS2331-240', 'UGC01479', 'UGC03478', 'UGC03995A', 'UGC05881', 'UGC07064', 'UGC08327NED02', 'UGC12237', 'UGC12741', 'VIIZw073']

# %% [markdown]
# I'm going to use the `Pandas` package to manage the data. This will allow us to easily combine the 500 $\mu$m excess measurements with the SPIRE colors using the names as the index.

# %%
excess_data = []

# Loop over all of the files
for f in files:
    fi = open(f, 'rb')
    d = pickle.load(fi)
    excess_data.append(d)
    fi.close()
    
excess500 = pd.DataFrame(excess_data, index=names)
print excess500
# Out:
#                                                                       all  \
# 2MASXJ07595347+2323241  [0.215166967566, 0.228616156621, 0.24064271225...
# 2MASXJ10402231-4625264  [0.213129009931, 0.225872656115, 0.22587265611...
# 2MASXJ12005792+0648226  [0.217158604128, 0.205182907657, 0.20518290765...
# 2MASXJ12313717-4758019  [0.352286900345, 0.352286900345, 0.35228690034...
# 2MASXJ15115979-2119015  [-0.0345517074211, -0.165591487629, -0.1655914...
# 2MASXJ19373299-0613046  [0.0366824304088, 0.268182920397, 0.2080255537...
# 2MASXJ21355399+4728217  [2.82350815457, 3.86449118576, 3.81535661941, ...
# 2MASXJ23272195+1524375  [1.06203693629, 0.981245262006, 0.981245262006...
# 2MFGC02280              [-0.0770331159895, -0.069366803052, -0.0508630...
# 3C111.0                 [0.832641198696, 0.596305631852, 0.52245173654...
# 3C120                   [0.67928507935, 0.67928507935, 0.679527564377,...
# 6dFJ0626586-370559      [0.242516088136, 0.242516088136, 0.24251608813...
# Ark120                  [0.103945650127, 0.103945650127, 0.10394565012...
# CenA                    [0.600011668106, 0.600011668106, 0.63237962988...
# CGCG341-006             [0.500669886547, 0.433224647348, 0.59905380238...
# CGCG468-002NED01        [-0.541827514135, -0.542180963523, -0.51139074...
# ESO005-G004             [0.212992493001, 0.214106445024, 0.21410644502...
# ESO033-G002             [0.376502560851, 0.376502560851, 0.37650256085...
# NGC7582                    0.448685
# NGC7603                    0.862546
# NGC7679                    0.715875
# NGC931                    78.639017
# NGC985                    44.056420
# PICTORA                 1762.008324
# PKS2331-240                2.422750
# UGC01479                   0.308316
# UGC03478                   0.393561
# UGC03995A                  0.566093
# UGC05881                   0.858920
# UGC07064                   1.854217
# UGC08327NED02              3.206065
# UGC12237                   0.524375
# UGC12741                   0.756951
# VIIZw073                   0.671761
#
# [140 rows x 7 columns]

# %% [markdown]
# Looking at the new excess500 DataFrame we can see that there are 7 columns: all, mean, p2_5, p_16, p_50, p_84, and p_97_5. The "all" column is just an array of all of the 500 $\mu$m excess measurements for the source. The rest represent the mean, 2.5, 16, 50, 84, and 97.5 percentiles for the excess measurements.
#
# The first thing I want to do is just look at the distribution of the 500 micron excess. For this I'll use a kernel density estimate for both the mean and 50th percentile to see if there is a big difference between the two. Naively I expect that the distributions should be dominated by a Gaussian centered on 0 with a small tail towards large values.
#
# I'll use the `Seaborn` package for easy visualization.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
sns.kdeplot(excess500['mean'][excess500['mean'] < 50], color=blue, shade=True, ax=ax1, bw=0.5)
ax1.set_xlabel('Excess')
sns.kdeplot(excess500['p50'], color=red, shade=True, ax=ax2)
ax2.axvline(0.134, color='k', lw=1)
ax2.set_xlabel('Excess')

# %% [markdown]
# For the mean to make the graph more readable I had to limit the excess measurement to be less than 50. I also manually set the bandwith to 0.5 to smooth it out some. Below I list the sources that are excluded using this cut for the mean 500 micorn excess measurement

# %%
excess500['mean'][excess500['mean'] > 50]
# Out:
# 3C111.0     61.870417
# PICTORA    212.406389
# Name: mean, dtype: float64

# %% [markdown]
# These are already known to be radio loud sources so its not surprising that they very high 500 micron excesses.
#
# In both plots we can see that the distribution of excess has a long tail towards high values and the main part is centered around 0. Although looking closely at the median distribution, its is slightly to right of "0" which means that the model we were using on average underpredicted the 500 micron flux. We can get an estimate of how much it was underpredicted by calculating the 50th percentile of the 'median' values.

# %%
median_excess500 = np.percentile(excess500['p50'], q=50.)
print 'Median 500 micron excess: ', median_excess500
# Out:
# Median 500 micron excess:  0.134287654298

# %% [markdown]
# So in a typical source the two temperature model underpredicted the observed 500 micron flux by approximately 13%. I show this value in the KDE plot as the black line.
#
# Lets take a look at the sources that have an excess that is above a certain threshold. Lets start with 1.0.

# %%
excess500['p50'][excess500['p50'] > 1.0]
# Out:
# 2MASXJ21355399+4728217    3.200826
# ESO362-18                 1.054146
# HB890241+622              3.723082
# PKS2331-240               1.974482
# UGC08327NED02             1.698434
# Name: p50, dtype: float64

# %%
excess500['p50'][excess500['p50'] > 0.5]
# Out:
# 2MASXJ12005792+0648226    0.532231
# 2MASXJ21355399+4728217    3.200826
# 2MASXJ23272195+1524375    0.903983
# 3C111.0                   0.694413
# 3C120                     0.996381
# 6dFJ0626586-370559        0.618873
# ESO033-G002               0.862914
# ESO362-18                 1.054146
# ESO509-IG066NED01         0.559399
# Fairall272                0.554815
# HB890241+622              3.723082
# LEDA170194                0.927547
# MCG+02-57-002             0.796806
# Mrk348                    0.643871
# Mrk618                    0.796385
# NGC985                    0.786330
# PICTORA                   0.734351
# PKS2331-240               1.974482
# UGC07064                  0.914557
# UGC08327NED02             1.698434
# Name: p50, dtype: float64

# %% [markdown]
# Now lets plot the SPIRE color-color diagram with the colors of the markers according to their 500 micron excess measurement.

# %%
# Upload the herschel data
data_dir = '/Users/ttshimiz/Research/Thesis/bat-data/'
herschel_data = pd.read_csv(data_dir+'bat_herschel.csv', index_col=0)

excess500['F250/F350'] = herschel_data['H_250']/herschel_data['H_350']
excess500['F350/F500'] = herschel_data['H_350']/herschel_data['H_500']

# %%
# Plot the SPIRE color-color diagram
fig1, ax1 = plt.subplots(1,1, figsize=(10, 7.5))
sc = ax1.scatter(excess500['F350/F500'], excess500['F250/F350'], c=excess500['p50'],
                s=50, marker='^', cmap = 'YlOrRd', vmax=1.0, vmin=0.0)
ax1.set_xlabel('F350/F500')
ax1.set_ylabel('F250/F350')
cbar = fig1.colorbar(sc, ax=ax1)
cbar.set_label('500 um Excess')

# Interactive features
import mpld3
mpld3.enable_notebook()
tooltip = mpld3.plugins.PointLabelTooltip(sc, labels=excess500.index.tolist())
mpld3.plugins.connect(fig1, tooltip)

# %% [markdown]
# Its definitely clear from the above plot that the 500 micron excess is causing the offset of the sources from the main correlation between the SPIRE colors. However we still don't know what is causing the excess. To try and determine that I'll look at the correlation between the 500 micron excess and various other indicators for the properties of the host galaxies.

# %% [markdown]
# The first obvious choice to look at is X-ray luminosity to see if possibly this is due to influence from the AGN.

# %%
import astropy.units as u

# Upload the BAT fluxes and distances to calculate the 14-195 keV luminosity.
gen_info = pd.read_csv('../../../bat-data/bat_info.csv', index_col=0)
bat_dat = pd.read_csv('../../../bat-data/bat_bat_flux.csv', index_col=0)
dist = np.array(gen_info['Dist_[Mpc]'])*u.Mpc

# Convert to 14-195 keV luminosity
bat_dat['LBAT'] = 4*np.pi*(dist.to(u.cm).value)**2*bat_dat.BAT_flux

# Add to the excess500 DataFrame
excess500['LBAT'] = bat_dat['LBAT']
excess500['Dist'] = gen_info['Dist_[Mpc]']

# %% [markdown]
# Before looking at the relationship I want to define a function that will plot everything the way I want to without having to call the same lines of code every time.

# %%
def plot_relationship(df, keyx, keyy, logx=False, logy=False):

    blue, green, red, purple, yellow, cyan = sns.color_palette('deep')
    fig, ax = plt.subplots(1, 1)
    df_clean = df[[keyx, keyy]].dropna(axis=0)
    if (logx == False) & (logy == False):
        pp = ax.scatter(df_clean[keyx], df_clean[keyy], c=blue, s=60, alpha=0.75, edgecolor='white')
        ax.set_xlabel(keyx)
        ax.set_ylabel(keyy)
    elif logx & logy:
        pp = ax.scatter(np.log10(df_clean[keyx]), np.log10(df_clean[keyy]), c=blue, s=60, alpha=0.75, edgecolor='white')
        ax.set_xlabel('log '+keyx)
        ax.set_ylabel('log '+keyy)
    elif logx:
        pp = ax.scatter(np.log10(df_clean[keyx]), df_clean[keyy], c=blue, s=60, alpha=0.75, edgecolor='white')
        ax.set_xlabel('log '+keyx)
        ax.set_ylabel(keyy)
    elif logy:
        pp = ax.scatter(df_clean[keyx], np.log10(df_clean[keyy]), c=blue, s=60, alpha=0.75, edgecolor='white')
        ax.set_xlabel(keyx)
        ax.set_ylabel('log '+keyy)
    tooltip = mpld3.plugins.PointLabelTooltip(pp, labels=df_clean.index.tolist())
    mpld3.plugins.connect(fig, tooltip)
    
    return fig

# %%
# Plot the relationship between X-ray luminosity and 500 micron excess
fig_lx = plot_relationship(excess500, 'LBAT', 'p50', logx=True)

# %% [markdown]
# Hmmm, it looks like there could be somewhat of a correlation between the two, especially above log(LBAT) = 43. This wasn't really noticeable when just looking at the SPIRE color-color plot with the points colored by LBAT. The sources that have really high 500 micron excess are definitely radio loud sources like HB890241, PKS2331, and 2MASXJ213553399.
#
# We should also look at radio loudness as a potential cause for the 500 micron excess. Earlier investigations by me didn't seem to point to this as some of the sources within the main SPIRE color-color correlation were also radio loud. But lets take a look anyway.
#
# There are two radio-loudness parameters I want to try.
# 1. $L_{1.4\,GHz}/L_{X-ray}$
# 2. $L_{1.4\,GHz}/L_{160\,\mu m}$
#
# For many of the sources we have the 1.4 GHz flux from either the NVSS or FIRST survey. However for some, mainly southern sources, we have 36 cm from the SUMSS survey and/or 5GHz fluxes from a literature search.
#
# We want to convert all the radio data to 1.4 GHz luminosity so what I will do for the sources that don't have 1.4 GHz fluxes, I'll assume a spectral index of -0.7 and extrapolate from either 36 cm (preferred) or 5GHz.
#
# Conversion to 1.4 GHz flux using assumption $F_{\nu} \propto \nu^{-0.7}$:
#
# $F_{\nu_{1}}/F_{\nu_{2}} = (\nu_{1}/\nu_{2})^{-0.7}$
#
# $F_{1.4\,GHz}/F_{5\,GHz} = (1.4\,GHz/5\,GHz)^{-0.7}$
#
# $F_{1.4\,GHz}/F_{843\,MHz} = (1.4\,GHz/843\,MHz)^{-0.7}$
#
# $F_{1.4\,GHz} = F_{5\,GHz}(1.4\,GHz/5\,GHz)^{-0.7}$
#
# $F_{1.4\,GHz} = F_{843\,MHz}(1.4\,GHz/843\,MHz)^{-0.7}$

# %%
# Import the radio fluxes
radio_1_4GHz = pd.read_csv('../../../bat-data/bat_20cm.csv', index_col=0)
radio_5GHz = pd.read_csv('../../../bat-data/bat_5GHz.csv', index_col=0)
radio_36cm = pd.read_csv('../../../bat-data/bat_sumss36cm.csv', index_col=0)

radio_5GHz['5GHz_to_20cm_flux'] = radio_5GHz['5GHz']*(1.4/5.0)**(-0.7)
radio_36cm['36cm_to_20cm_flux'] = radio_36cm.SUMSS_36cm*(1.4/0.843)**(-0.7)

data = excess500.join(radio_1_4GHz)
data = data.join(radio_36cm)
data = data.join(radio_5GHz)

# Calculate 1.4 GHz luminosity. Use actual 1.4 GHz fluxes first, then 843 MHz, then 5 GHz
data['L20cm'] = 4*np.pi*((np.array(data['Dist'])*u.Mpc).to(u.cm))**2*data['20cm_flux']*(1.4e9)*10**(-23)
a = pd.DataFrame({'L20cm':4*np.pi*((np.array(data['Dist'])*u.Mpc).to(u.cm).value)**2*data['36cm_to_20cm_flux']*(1.4e9)*10**(-23)})
b = pd.DataFrame({'L20cm':4*np.pi*((np.array(data['Dist'])*u.Mpc).to(u.cm).value)**2*data['5GHz_to_20cm_flux']*(1.4e9)*10**(-23)})
data = data.combine_first(a)
data = data.combine_first(b)

# Radio Loudness 1 = L20cm/LBAT
data['R1'] = data['L20cm']/data['LBAT']

# Radio Loudness 2 = L20cm/L160
l160 = 4*np.pi*(dist.to(u.cm).value)**2*(3e10/160e-4)*herschel_data['H_160']*10**(-23)
data['L160'] = l160
data['R2'] = data['L20cm']/data['L160']

# Plot the relationship between R1 and 500 micron excess
fig_r1 = plot_relationship(data, 'R1', 'p50', logx=True)

# %%
# Plot the relationship between R2 and 500 micron excess
fig_r2 = plot_relationship(data, 'R2', 'p50', logx=True)

# %% [markdown]
# There does not seem to be much of a relationship between the radio loudness and the 500 micron excess. Obviously some of the sources that have a 500 micron excess are very radio loud, but that doesn't seem to true for all of the sources.

# %% [markdown]
# The next indicator I want to test is the WISE Color: W1/W2.

# %%
# Import the WISE data
wise_data = pd.read_csv('../../../bat-data/bat_wise.csv', index_col=0)
data['W1/W2'] = wise_data.W1/wise_data.W2

fig_wise = plot_relationship(data, 'W1/W2', 'p50')

# %% [markdown]
# There definitely seems to be a relationhip between 500 micron excess and W1/W2! The wise color is usually used as an indicator of morphology I believe with smaller ratios indicating more AGN influence. That would certainly make sense since we see a correlation between 500 micron excess and LBAT.
#
# However, the group of 5 sources at slightly above W1/W2 = 1.0 and around p50 = 1.0 are the sources that make up the end of the "arm" in the offset SPIRE color-color sourcs. So W1/W2 doesn't fully explain the source of the 500 micron excess.
#
# Some of the outlier sourcs are known radio-loud sources: HB89-0241 and PKS2331-240. However two of them (2MASXJ2135399 and UGC08327NEDO2) aren't radio loud as seen in the above two plots. UGC08327NED02 is a merger so most likely what's happening is that there is increasing contamination as the PSF gets worse. 2MASXJ21355399 has a Galactic latitude of -3 degrees so it is well within the galactic plane and is most likely suffering from cirrus contamination from the MW.

# %% [markdown]
# The last indicator I want to look at is the ratio of the AGN to star formation. For this I'll use LBAT for the AGN and L160 for star formation.

# %%
data['L160/LBAT'] = data.L160/data.LBAT
fig_agn_sf = plot_relationship(data, 'L160/LBAT', 'p50', logx=True)

# %% [markdown]
# This seems to work really well in explaining the 500 micron excess. Higher excess is correlated with lower ratio of L160/LBAT meaning star formation weaker given an AGN strength. So the next question then is why does this cause a 500 micron excess??
